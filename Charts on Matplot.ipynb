# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('chart types.csv')
data
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83
# 5  1670  2.91
# 6  1764  3.00
# 7  1764  3.00
# 8  1792  3.01

# %%
x= data['SAT']
y= data['GPA']

# %% [markdown]
# ###*BAR CHART*

# %%
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.pie(data['SAT'], labels = data['GPA'], autopct =' %.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d33f6e090>,
# ...
#  [Text(1.0343377565594383, 0.37435999433110995, '2.4'),
#   Text(0.5647302689369638, 0.9439701919798023, '2.52'),
#   Text(-0.16936987512353754, 1.086882627242076, '2.54'),
#   Text(-0.8282654730310198, 0.7238620767692565, '2.74'),
#   Text(-1.0993704143013385, 0.037211451985959675, '2.83'),
#   Text(-0.8773368089274604, -0.6635360756590263, '2.91'),
#   Text(-0.24812413437460687, -1.0716503226056773, '3.0'),
#   Text(0.5150319859544082, -0.9719784223139207, '3.0'),
#   Text(1.0282927651551386, -0.3906584046575718, '3.01')],
#  [Text(0.5641842308506025, 0.20419636054424176, ' 11.05%'),
#   Text(0.3080346921474348, 0.5148928319889831, ' 10.73%'),
#   Text(-0.0923835682492023, 0.5928450694047687, ' 11.35%'),
#   Text(-0.45178116710782895, 0.39483386005595805, ' 10.87%'),
#   Text(-0.5996565896189119, 0.020297155628705273, ' 10.92%'),
#   Text(-0.47854735032406925, -0.361928768541287, ' 10.77%'),
# ...
